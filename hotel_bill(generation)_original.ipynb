# %%
import datetime as t

tables={"table1":{"id":1,"capacity":2,"occupancy":False},"table2":{"id":2,"capacity":4,"occupancy":False},
        "table3":{"id":3,"capacity":6,"occupancy":False},
       "table4":{"id":4,"capacity":8,"occupancy":False}}

def assign_table(table_dict,cap):
   
    for table, status in table_dict.items():
       
        if tables[table]["capacity"]==cap:
            table_dict[table]["occupancy"] = True
            waiters=dict(zip(table_dict[table],str(table_dict[table]["id"])))
           
            return tables,waiters
       
       
def mark_table_as_unoccupied(table_dict, table_name):
   
    if table_name in table_dict:
        table_dict[table_name]["occupancy"]=False
        return tables
   
tea=7
idly=30
dosa=50
wada=40
puri=40
upma=30
bonda=40
def rest(items):
    b=0
    for i in items:
        if i=="idly":
            b=b+idly
        if i=="dosa":
            b=b+dosa
        if i=="wada":
            b=b+wada
        if i=="tea":
            b=b+tea
        if i=="puri":
            b=b+puri
        if i=="bonda":
            b=b+bonda
        if i=="upma":
            b=b+upma
       
    return b


#h=open("my_per.txt","a")
   
while True:
       
    action = input("Enter 'sit' to seat customers, 'leave' to  table unoccupy, or 'out' to out: ")
    print()
   
    if action == 'sit':
        cap=int(input("enter no.of persons:"))
       
        print()
       
        for m,n in tables.items():
            if tables[m]["capacity"]==cap:
                print("Welcome sir!")
                print()
                print("please be sit in:",m)
                print()
           
       
       
       
        table_assigned,waiter = assign_table(tables,cap)
        print(table_assigned)
        print()
       
        print("""------------------🅼🅰🅳🅷🆄 🆃🅴🅰 🅰🅽🅳 🆃🅸🅵🅵🅸🅽🆂---------------""")
        print()
        menu={"Tea":7,"Idly":30,"Wada":40,"Dosa":50,"Bonda":40,"Puri":40,"upma":30}
       
        print("-----------------------------------")

        headers=["item",'price']

        print(f"{headers[0]:<10}{headers[1]}")
        print("-----------------------------------")

        for i,j in menu.items():
            print(f"{i:<10}{j}/-")

        print()
       
        items=[]
       
        order=False
       
        while not order:
           
            customer=input("select items from the menu/no to stop:")  
            items.append(customer)
            bill=rest(items)
           
            if customer=="no":
               
                print()
                print("""------------------🅼🅰🅳🅷🆄 🆃🅴🅰 🅰🅽🅳 🆃🅸🅵🅵🅸🅽🆂---------------""")
                print()
                print("-----------------------------------")
               
                q=["Item","Price"]
                print("___________________________________")
                print(f"{q[0]:<15}{q[1]}")
                print("-----------------------------------")
               

                for i in items:
                    if i=="idly":
                        print(f"{i:<15}{idly}/-")
                    if i=="dosa":
                        print(f"{i:<15}{dosa}/-")
                    if i=="wada":
                        print(f"{i:<15}{wada}/-")
                    if i=="tea":
                        print(f"{i:<15}{tea}/-")
                    if i=="bonda":
                        print(f"{i:<15}{bonda}/-")
                    if i=="puri":
                        print(f"{i:<15}{puri}/-")
                    if i=="upma":
                        print(f"{i:<15}{upma}/-")
                print("___________________________________")
                print("Total bill=",bill,"/-")
                print("___________________________________")
                n=t.datetime.now()
                print()
                print(f"waiter id who handled table is {waiter} at Time= {n.hour}:{n.minute}a.m")
                print("-------------------------------------------------------------------------")
             
               
               
               
               
               
                #for q,w in table_assigned.items():
                    #if table_assigned[q]["capacity"]==cap:
                       
                        #h.write(f"total bill of {q} is= {str(bill)} and ")
           
                #for k,v in waiter.items():
                   
                    #h.write(f"waiter who handled is ={k}:")
                    #h.write(v)
                #h.write(f" at time={n}\n")
               
           
                order=True
           
       

    elif action == 'leave':
        print()
        print("------Remainder---Please collect bill before they leave")
        print()
        print("The Below list shows The Table  persons who alredy paid bill :")
        left=[]
        for y,l in table_assigned.items():
            if table_assigned[y]["occupancy"]==True:
                left.append(y)
        print()
        print(left)
        print()
                     
       
               
        print("Please----provide Rating on your Order!")
        print()
        print("Please ask the rating from above displayed table customers")
        d={}
        for i in range(len(left)):
            t_r=input("enter table no. who gives rating:")
            rating=input("enter rating from 1 to 5 :")
            d[t_r]=rating
            print()
        print(d)
        print("Thank-you")              
                     
                     
   
        print()

       
       
       
       


        table_to_leave = input("Enter the table to mark as unoccupied: ")
        print()

        a=mark_table_as_unoccupied(tables, table_to_leave)

        print(a)
        print()
       
       
       
    elif action == 'out':
        print("Thank you-Visit again")
        break
       
       
       

#h.close()end
# Out:
# Enter 'sit' to seat customers, 'leave' to  table unoccupy, or 'out' to out: sit
#
# enter no.of persons:4
#
# Welcome sir!
#
# please be sit in: table2
#
# {'table1': {'id': 1, 'capacity': 2, 'occupancy': False}, 'table2': {'id': 2, 'capacity': 4, 'occupancy': True}, 'table3': {'id': 3, 'capacity': 6, 'occupancy': False}, 'table4': {'id': 4, 'capacity': 8, 'occupancy': False}}
#
# ------------------🅼🅰🅳🅷🆄 🆃🅴🅰 🅰🅽🅳 🆃🅸🅵🅵🅸🅽🆂---------------
#
# -----------------------------------
# item      price
# -----------------------------------
# Tea       7/-
# Idly      30/-
# Wada      40/-
# Dosa      50/-
# Bonda     40/-
# Puri      40/-
# upma      30/-
#
# select items from the menu/no to stop:tea
# select items from the menu/no to stop:wada
# select items from the menu/no to stop:no
#
# ------------------🅼🅰🅳🅷🆄 🆃🅴🅰 🅰🅽🅳 🆃🅸🅵🅵🅸🅽🆂---------------
#
# -----------------------------------
# ___________________________________
# Item           Price
# -----------------------------------
# ...
